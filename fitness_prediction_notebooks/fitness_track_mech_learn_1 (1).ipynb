# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score

# %%
df=pd.read_csv("/content/fitness_tracker_dataset.csv")
df
# Out:
#         user_id        date  steps  calories_burned  distance_km  \
# 0           468  2023-01-01   4530          2543.02        16.10
# 1           879  2023-01-01  11613          1720.76         8.10
# 2           152  2023-01-01  27335          1706.35         3.57
# 3           311  2023-01-01  13459          2912.38         6.41
# 4           759  2023-01-01  15378          3344.51        17.88
# ...         ...         ...    ...              ...          ...
# 364995      251  2023-12-31  14298          3333.78         5.57
# 364996      314  2023-12-31  14751          2465.31        17.93
# 364997       58  2023-12-31   3340          2078.38        13.87
# 364998      606  2023-12-31  16148          3279.38         6.06
# 364999      279  2023-12-31  15850          1856.99         8.51
#
#         active_minutes  sleep_hours  heart_rate_avg workout_type  \
# 0                  613          1.5             176      Walking
# ...

# %%
df.tail(15)
# Out:
#         user_id        date  steps  calories_burned  distance_km  \
# 364985      739  2023-12-31  11390          3417.21        17.78
# 364986      742  2023-12-31  24272          3444.65        19.84
# 364987      432  2023-12-31   5533          3130.37        11.65
# 364988      253  2023-12-31  24323          2161.66        19.69
# 364989      454  2023-12-31   3089          2707.34        16.02
# 364990      759  2023-12-31  24470          3040.65         7.44
# 364991      853  2023-12-31  20430          2258.27         2.57
# 364992      337  2023-12-31  11778          2951.83         0.77
# 364993      792  2023-12-31   3088          1840.61        14.21
# 364994      933  2023-12-31   5061          1816.55         1.36
# 364995      251  2023-12-31  14298          3333.78         5.57
# 364996      314  2023-12-31  14751          2465.31        17.93
# 364997       58  2023-12-31   3340          2078.38        13.87
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365000 entries, 0 to 364999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   user_id             365000 non-null  int64
#  1   date                365000 non-null  object
#  2   steps               365000 non-null  int64
#  3   calories_burned     365000 non-null  float64
#  4   distance_km         365000 non-null  float64
#  5   active_minutes      365000 non-null  int64
#  6   sleep_hours         365000 non-null  float64
#  7   heart_rate_avg      365000 non-null  int64
#  8   workout_type        312847 non-null  object
#  9   weather_conditions  365000 non-null  object
#  10  location            365000 non-null  object
#  11  mood                365000 non-null  object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 33.4+ MB

# %%
df.columns
# Out:
# Index(['user_id', 'date', 'steps', 'calories_burned', 'distance_km',
#        'active_minutes', 'sleep_hours', 'heart_rate_avg', 'workout_type',
#        'weather_conditions', 'location', 'mood'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# user_id                   0
# date                      0
# steps                     0
# calories_burned           0
# distance_km               0
# active_minutes            0
# sleep_hours               0
# heart_rate_avg            0
# workout_type          52153
# weather_conditions        0
# location                  0
# mood                      0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder=LabelEncoder()

df[['date']]=df[['date']].apply(LabelEncoder().fit_transform)

# %%
df
# Out:
#         user_id  date  steps  calories_burned  distance_km  active_minutes  \
# 0           468     0   4530          2543.02        16.10             613
# 1           879     0  11613          1720.76         8.10             352
# 2           152     0  27335          1706.35         3.57             236
# 3           311     0  13459          2912.38         6.41            1329
# 4           759     0  15378          3344.51        17.88              52
# ...         ...   ...    ...              ...          ...             ...
# 364995      251   364  14298          3333.78         5.57             942
# 364996      314   364  14751          2465.31        17.93             590
# 364997       58   364   3340          2078.38        13.87            1137
# 364998      606   364  16148          3279.38         6.06            1107
# 364999      279   364  15850          1856.99         8.51             168
#
# ...

# %%
df1=pd.get_dummies(df[['workout_type','location','weather_conditions','mood']],drop_first=True)

# %%
df1.head()
# Out:
#    workout_type_Gym Workout  workout_type_Running  workout_type_Swimming  \
# 0                     False                 False                  False
# 1                     False                 False                  False
# 2                     False                 False                  False
# 3                     False                 False                   True
# 4                     False                 False                   True
#
#    workout_type_Walking  workout_type_Yoga  location_Home  location_Office  \
# 0                  True              False          False            False
# 1                 False              False          False            False
# 2                 False               True          False            False
# 3                 False              False          False             True
# 4                 False              False          False             True
#
#    location_Other  location_Park  weather_conditions_Fog  \
# ...

# %%
df2=pd.concat([df,df1],axis=1)

# %%
df2.head()
# Out:
#    user_id  date  steps  calories_burned  distance_km  active_minutes  \
# 0      468     0   4530          2543.02        16.10             613
# 1      879     0  11613          1720.76         8.10             352
# 2      152     0  27335          1706.35         3.57             236
# 3      311     0  13459          2912.38         6.41            1329
# 4      759     0  15378          3344.51        17.88              52
#
#    sleep_hours  heart_rate_avg workout_type weather_conditions  ...  \
# 0          1.5             176      Walking              Clear  ...
# 1          6.3             128      Cycling                Fog  ...
# 2          6.7             134         Yoga               Snow  ...
# 3         11.6             116     Swimming               Rain  ...
# 4          7.4              84     Swimming               Rain  ...
#
#   location_Home location_Office  location_Other  location_Park  \
# 0         False           False           False           True
# ...

# %%
df2.columns
# Out:
# Index(['user_id', 'date', 'steps', 'calories_burned', 'distance_km',
#        'active_minutes', 'sleep_hours', 'heart_rate_avg', 'workout_type',
#        'weather_conditions', 'location', 'mood', 'workout_type_Gym Workout',
#        'workout_type_Running', 'workout_type_Swimming', 'workout_type_Walking',
#        'workout_type_Yoga', 'location_Home', 'location_Office',
#        'location_Other', 'location_Park', 'weather_conditions_Fog',
#        'weather_conditions_Rain', 'weather_conditions_Snow', 'mood_Neutral',
#        'mood_Stressed', 'mood_Tired'],
#       dtype='object')

# %%
df3=df2.drop(['workout_type','location','weather_conditions','mood'],axis=1)

# %%
df3.columns
# Out:
# Index(['user_id', 'date', 'steps', 'calories_burned', 'distance_km',
#        'active_minutes', 'sleep_hours', 'heart_rate_avg',
#        'workout_type_Gym Workout', 'workout_type_Running',
#        'workout_type_Swimming', 'workout_type_Walking', 'workout_type_Yoga',
#        'location_Home', 'location_Office', 'location_Other', 'location_Park',
#        'weather_conditions_Fog', 'weather_conditions_Rain',
#        'weather_conditions_Snow', 'mood_Neutral', 'mood_Stressed',
#        'mood_Tired'],
#       dtype='object')

# %%
x = df3.iloc[:,0:-3].values
x
# Out:
# array([[468, 0, 4530, ..., False, False, False],
#        [879, 0, 11613, ..., True, False, False],
#        [152, 0, 27335, ..., False, False, True],
#        ...,
#        [58, 364, 3340, ..., True, False, False],
#        [606, 364, 16148, ..., True, False, False],
#        [279, 364, 15850, ..., True, False, False]], dtype=object)

# %%
y = df3.iloc[:,-3].values
y
# Out:
# array([False, False,  True, ..., False, False, False])

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 42)

# %%
print("x_train: ",x_train.shape)
print("y_train: ",y_train.shape)
print("x_test: ",x_test.shape)
print("y_test: ",y_test.shape)
# Out:
# x_train:  (255500, 20)
# y_train:  (255500,)
# x_test:  (109500, 20)
# y_test:  (109500,)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model_rf = RandomForestClassifier(n_estimators = 30, criterion = 'entropy', random_state = 42)

# %%
model_rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=30, random_state=42)

# %%
y_pred_rf = model_rf.predict(x_test)

# %%
y_pred_rf
# Out:
# array([False, False, False, ..., False, False, False])

# %%
print("Accuracy : ", accuracy_score(y_test, y_pred_rf))
# Out:
# Accuracy :  0.7484018264840183
